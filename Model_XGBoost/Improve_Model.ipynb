# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv("train_values.csv", delimiter=',')

# %%
train_data.columns
# Out:
# Index(['building_id', 'geo_level_1_id', 'geo_level_2_id', 'geo_level_3_id',
#        'count_floors_pre_eq', 'age', 'area_percentage', 'height_percentage',
#        'land_surface_condition', 'foundation_type', 'roof_type',
#        'ground_floor_type', 'other_floor_type', 'position',
#        'plan_configuration', 'has_superstructure_adobe_mud',
#        'has_superstructure_mud_mortar_stone', 'has_superstructure_stone_flag',
#        'has_superstructure_cement_mortar_stone',
#        'has_superstructure_mud_mortar_brick',
#        'has_superstructure_cement_mortar_brick', 'has_superstructure_timber',
#        'has_superstructure_bamboo', 'has_superstructure_rc_non_engineered',
#        'has_superstructure_rc_engineered', 'has_superstructure_other',
#        'legal_ownership_status', 'count_families', 'has_secondary_use',
#        'has_secondary_use_agriculture', 'has_secondary_use_hotel',
#        'has_secondary_use_rental', 'has_secondary_use_institution',
# ...

# %%
train_data['volume_percantage'] = train_data['area_percentage'] * train_data['height_percentage']

# %%
drop_features = ['building_id', 'geo_level_1_id', 'geo_level_2_id', 'geo_level_3_id', 'area_percentage', 'height_percentage']

# %%
dropped_data = train_data.drop(drop_features, axis=1)

# %%
dropped_data.head()
# Out:
#    count_floors_pre_eq  age land_surface_condition foundation_type roof_type  \
# 0                    2   30                      t               r         n
# 1                    2   10                      o               r         n
# 2                    2   10                      t               r         n
# 3                    2   10                      t               r         n
# 4                    3   30                      t               r         n
#
#   ground_floor_type other_floor_type position plan_configuration  \
# 0                 f                q        t                  d
# 1                 x                q        s                  d
# 2                 f                x        t                  d
# 3                 f                x        s                  d
# 4                 f                x        s                  d
#
#    has_superstructure_adobe_mud  ...  has_secondary_use_hotel  \
# ...

# %%
dropped_data.to_csv('dropped_data.csv', index=False)

# %%
binary_data = pd.get_dummies(dropped_data)

# %%
binary_data.head()
# Out:
#    count_floors_pre_eq  age  has_superstructure_adobe_mud  \
# 0                    2   30                             1
# 1                    2   10                             0
# 2                    2   10                             0
# 3                    2   10                             0
# 4                    3   30                             1
#
#    has_superstructure_mud_mortar_stone  has_superstructure_stone_flag  \
# 0                                    1                              0
# 1                                    1                              0
# 2                                    1                              0
# 3                                    1                              0
# 4                                    0                              0
#
#    has_superstructure_cement_mortar_stone  \
# 0                                       0
# 1                                       0
# 2                                       0
# ...

# %%
binary_data.to_csv('binary_data.csv', index=False)
