# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv("train_values.csv", delimiter=',')

# %%
train_labels = pd.read_csv("train_labels.csv", delimiter=",")

# %%
train_damage_grade = train_labels['damage_grade']

information = train_data['geo_level_2_id']

# %%
full_data = train_data
full_data['damage_grade'] = train_damage_grade

# %%
full_data.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type  ... has_secondary_use_hotel  \
# 0                      t               r  ...                       0
# ...

# %%
df = pd.DataFrame({'information':information, 'damage_grade':train_damage_grade})

# %%
grouped = df.groupby(['information']).damage_grade.agg([sum, len])

# %%
grouped.head()
# Out:
#              sum  len
# information
# 0            105   38
# 1            479  204
# 3            162   77
# 4            794  315
# 5             54   25

# %%
grouped['mean'] = (grouped['sum'] // grouped['len'])

# %%
features = ['age','area_percentage','height_percentage', 'has_secondary_use_institution'  , 'damage_grade']

compare_df = full_data[features]

# %%
cmap = sns.diverging_palette(h_neg=10, h_pos=240, as_cmap=True)
sns.heatmap(compare_df.corr(), center=0,cmap=cmap, linewidths=1, annot=True, fmt=".2f")

# %%
full_data['age'].unique()
# Out:
# array([ 30,  10,  25,   0,  15,  20,  45,  55,   5,  40,  80,  60,  35,
#         70,  50,  65, 100,  75,  85, 190, 995, 105,  90, 120,  95, 110,
#        115, 150, 200, 130, 125, 140, 155, 160, 175, 135, 145, 195, 180,
#        165, 170, 185], dtype=int64)

# %%
condition = full_data['age'] == 995

# %%
full_data[condition].groupby('damage_grade').head()
# Out:
#       building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 386        435557              14            1120            3789
# 716        597626              26              39            1851
# 1235         7560              26            1132            9472
# 1398       797271              26              39            1851
# 1635       857371              24             628           10750
# 2148       829384              27             181            2607
# 2370       132439              14            1120            6614
# 2851       382719               6            1002            4558
# 2869       637115              12             339            9506
# 2890       773289               6            1002            3931
# 2899       150430               7             641            8738
# 3286       277074              12             339            9506
# 3616        32070              27             390            9360
# ...
